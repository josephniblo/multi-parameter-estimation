# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Load the data

# %%
# Set to True to force a full refresh of the data
full_refresh = True

# %%
repo_root = os.popen('git rev-parse --show-toplevel').read().strip()

# %%
data_folder = os.path.join(repo_root, 'multi-parameter-estimation', 'data')

# Get list of data directories
data_dirs = os.listdir(data_folder)
data_dirs = [d for d in data_dirs if os.path.isdir(os.path.join(data_folder, d))]

# skip old-data
if 'old-data' in data_dirs:
    data_dirs.remove('old-data')

data_dirs.sort()
data_dirs
# Out:
# ['2025-07-03--15h-44m-51s',
#  '2025-07-03--16h-11m-36s',
#  '2025-07-03--16h-16m-56s',
#  '2025-07-03--16h-22m-15s',
#  '2025-07-03--16h-27m-19s',
#  '2025-07-03--16h-36m-39s',
#  '2025-07-03--16h-42m-17s',
#  '2025-07-07--11h-59m-57s',
#  '2025-07-07--12h-05m-34s',
#  '2025-07-07--12h-12m-21s',
#  '2025-07-07--12h-19m-57s',
#  '2025-07-07--14h-31m-04s',
#  '2025-07-07--14h-37m-06s',
#  '2025-07-07--14h-45m-36s',
#  '2025-07-07--14h-51m-58s',
#  '2025-07-07--14h-57m-39s',
#  '2025-07-08--10h-30m-07s',
#  '2025-07-08--10h-35m-04s',
#  '2025-07-08--10h-40m-12s',
#  '2025-07-08--10h-45m-36s',
#  '2025-07-08--10h-56m-10s',
#  '2025-07-08--11h-01m-30s',
#  '2025-07-08--11h-06m-45s']

# %%
new_data_dirs = data_dirs.copy()

if not full_refresh:
    for d in data_dirs:
        if os.path.exists(os.path.join(data_folder, d, "scaled_coincidences.csv")):
            new_data_dirs.remove(d)

new_data_dirs
# Out:
# ['2025-07-03--15h-44m-51s',
#  '2025-07-03--16h-11m-36s',
#  '2025-07-03--16h-16m-56s',
#  '2025-07-03--16h-22m-15s',
#  '2025-07-03--16h-27m-19s',
#  '2025-07-03--16h-36m-39s',
#  '2025-07-03--16h-42m-17s',
#  '2025-07-07--11h-59m-57s',
#  '2025-07-07--12h-05m-34s',
#  '2025-07-07--12h-12m-21s',
#  '2025-07-07--12h-19m-57s',
#  '2025-07-07--14h-31m-04s',
#  '2025-07-07--14h-37m-06s',
#  '2025-07-07--14h-45m-36s',
#  '2025-07-07--14h-51m-58s',
#  '2025-07-07--14h-57m-39s',
#  '2025-07-08--10h-30m-07s',
#  '2025-07-08--10h-35m-04s',
#  '2025-07-08--10h-40m-12s',
#  '2025-07-08--10h-45m-36s',
#  '2025-07-08--10h-56m-10s',
#  '2025-07-08--11h-01m-30s',
#  '2025-07-08--11h-06m-45s']

# %%
def load_coincidences(data_dir):
    coincidences = pd.read_csv(os.path.join(data_folder, data_dir, "labelled_coincidences.csv"))
    coincidences["data_dir"] = data_dir
    return coincidences

coincidences_df = pd.concat([load_coincidences(d) for d in new_data_dirs], ignore_index=True)
coincidences_df
# Out:
#          detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                      9               12      552668721563163
# 1                      1                4      552668723130306
# 2                      9               12      552668723321214
# 3                      9               12      552668723471264
# 4                      1                4      552668723517406
# ...                  ...              ...                  ...
# 2171136               10               11 -4242167837918237184
# 2171137                1               12 -4242167837917572096
# 2171138               10               11 -4242167837917491712
# 2171139                1                4 -4242167837917381120
# 2171140                4                7 -4242167837917214208
#
#          detector_b_time_tag                timestamp tomography_setting_t  \
# 0            552668721563158  2025-07-03--15h-45m-02s                    H
# 1            552668723130306  2025-07-03--15h-45m-02s                    H
# 2            552668723321211  2025-07-03--15h-45m-02s                    H
# 3            552668723471260  2025-07-03--15h-45m-02s                    H
# 4            552668723517406  2025-07-03--15h-45m-02s                    H
# ...                      ...                      ...                  ...
# 2171136 -4242167837918237184  2025-07-08--11h-08m-01s                    V
# 2171137 -4242167837917572096  2025-07-08--11h-08m-01s                    V
# 2171138 -4242167837917491712  2025-07-08--11h-08m-01s                    V
# 2171139 -4242167837917381120  2025-07-08--11h-08m-01s                    V
# 2171140 -4242167837917214208  2025-07-08--11h-08m-02s                    V
#
#         tomography_setting_r                 data_dir estimation_label  \
# 0                          H  2025-07-03--15h-44m-51s             DB_H
# 1                          H  2025-07-03--15h-44m-51s             DB_H
# 2                          H  2025-07-03--15h-44m-51s             DB_H
# 3                          H  2025-07-03--15h-44m-51s             DB_H
# 4                          H  2025-07-03--15h-44m-51s             DB_H
# ...                      ...                      ...              ...
# 2171136                    H  2025-07-08--11h-06m-45s             DB_H
# 2171137                    H  2025-07-08--11h-06m-45s                C
# 2171138                    H  2025-07-08--11h-06m-45s             DB_H
# 2171139                    H  2025-07-08--11h-06m-45s             DB_H
# 2171140                    H  2025-07-08--11h-06m-45s               SB
#
#         corrected_estimation_label
# 0                               HH
# 1                               HH
# 2                               HH
# 3                               HH
# 4                               HH
# ...                            ...
# 2171136                         HH
# 2171137                         C'
# 2171138                         HH
# 2171139                         HH
# 2171140                         SB
#
# [2171141 rows x 10 columns]

# %% [markdown]
# # Interleave the different tomography settings

# %%
first_tags_in_tomo_settings = coincidences_df.groupby(["data_dir", "tomography_setting_t", "tomography_setting_r"])["detector_a_time_tag"].first().reset_index()
first_tags_in_tomo_settings
# Out:
#                    data_dir tomography_setting_t tomography_setting_r  \
# 0   2025-07-03--15h-44m-51s                    H                    H
# 1   2025-07-03--15h-44m-51s                    H                    V
# 2   2025-07-03--15h-44m-51s                    V                    H
# 3   2025-07-03--15h-44m-51s                    V                    V
# 4   2025-07-03--16h-11m-36s                    H                    H
# ..                      ...                  ...                  ...
# 87  2025-07-08--11h-01m-30s                    V                    V
# 88  2025-07-08--11h-06m-45s                    H                    H
# 89  2025-07-08--11h-06m-45s                    H                    V
# 90  2025-07-08--11h-06m-45s                    V                    H
# 91  2025-07-08--11h-06m-45s                    V                    V
#
#     detector_a_time_tag
# 0       552668721563163
# 1       552778373836228
# 2       552989482045607
# 3       552883897914109
# 4       562990035523668
# ..                  ...
# 87 -4242169885540854784
# 88 -4242168176735174144
# 89 -4242168067595898880
# 90 -4242167850694461440
# 91 -4242167958750304256
#
# [92 rows x 4 columns]

# %%
coincidences_df["first_tag_in_tomo_setting"] = coincidences_df.merge(
    first_tags_in_tomo_settings,
    on=["data_dir", "tomography_setting_t", "tomography_setting_r"],
    how="left",
    suffixes=("", "_first")
)["detector_a_time_tag_first"]
coincidences_df["relative_time_tag"] = coincidences_df["detector_a_time_tag"] - coincidences_df["first_tag_in_tomo_setting"]
coincidences_df = coincidences_df.drop(columns=["first_tag_in_tomo_setting"])
coincidences_df = coincidences_df.sort_values(by=["data_dir", "relative_time_tag"])
coincidences_df = coincidences_df.reset_index(drop=True)
coincidences_df
# Out:
#          detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                      9               12      552668721563163
# 1                     11               12      552778373836228
# 2                     10               11      552883897914109
# 3                     10               11      552989482045607
# 4                      1                4      552989482325355
# ...                  ...              ...                  ...
# 2171136                7               10 -4242168054817446400
# 2171137                1               10 -4242167945971833344
# 2171138                1                7 -4242168054817103872
# 2171139                1               10 -4242168163956007936
# 2171140                9               12 -4242168054816606720
#
#          detector_b_time_tag                timestamp tomography_setting_t  \
# 0            552668721563158  2025-07-03--15h-45m-02s                    H
# 1            552778373836227  2025-07-03--15h-45m-18s                    H
# 2            552883897914105  2025-07-03--15h-45m-35s                    V
# 3            552989482045603  2025-07-03--15h-45m-51s                    V
# 4            552989482325354  2025-07-03--15h-45m-51s                    V
# ...                      ...                      ...                  ...
# 2171136 -4242168054817446400  2025-07-08--11h-07m-28s                    H
# 2171137 -4242167945971833344  2025-07-08--11h-07m-44s                    V
# 2171138 -4242168054817103872  2025-07-08--11h-07m-27s                    H
# 2171139 -4242168163956007936  2025-07-08--11h-07m-10s                    H
# 2171140 -4242168054816606720  2025-07-08--11h-07m-27s                    H
#
#         tomography_setting_r                 data_dir estimation_label  \
# 0                          H  2025-07-03--15h-44m-51s             DB_H
# 1                          V  2025-07-03--15h-44m-51s               SB
# 2                          V  2025-07-03--15h-44m-51s             DB_H
# 3                          H  2025-07-03--15h-44m-51s             DB_H
# 4                          H  2025-07-03--15h-44m-51s             DB_H
# ...                      ...                      ...              ...
# 2171136                    V  2025-07-08--11h-06m-45s                C
# 2171137                    V  2025-07-08--11h-06m-45s                C
# 2171138                    V  2025-07-08--11h-06m-45s               SB
# 2171139                    H  2025-07-08--11h-06m-45s                C
# 2171140                    V  2025-07-08--11h-06m-45s             DB_H
#
#         corrected_estimation_label  relative_time_tag
# 0                               HH                  0
# 1                               SB                  0
# 2                               HH                  0
# 3                               HH                  0
# 4                               HH             279748
# ...                            ...                ...
# 2171136                         C'        12778452480
# 2171137                         C'        12778470912
# 2171138                         SB        12778795008
# 2171139                         C'        12779166208
# 2171140                         HH        12779292160
#
# [2171141 rows x 11 columns]

# %% [markdown]
# # Remove half the non-double bunched events

# %%
# count the number of non-double-bunched events
non_double_bunched_count = coincidences_df[coincidences_df["estimation_label"].isin(["C", "SB"])].count()["estimation_label"]
number_to_remove = int(non_double_bunched_count * 0.5)

mask = np.zeros(len(coincidences_df), dtype=bool)
mask[coincidences_df["estimation_label"].isin(["C", "SB"])] = True
np.random.seed(42)  # For reproducibility
indices_to_remove = np.random.choice(np.where(mask)[0], size=number_to_remove, replace=False)
coincidences_df = coincidences_df.drop(indices_to_remove).reset_index(drop=True)
coincidences_df
# Out:
#          detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                      9               12      552668721563163
# 1                     10               11      552883897914109
# 2                     10               11      552989482045607
# 3                      1                4      552989482325355
# 4                     10               11      552989482855136
# ...                  ...              ...                  ...
# 1691021                4               10 -4242167945972078080
# 1691022                1                4 -4242168163956942336
# 1691023                2                9 -4242168163956753920
# 1691024                7               10 -4242168054817446400
# 1691025                9               12 -4242168054816606720
#
#          detector_b_time_tag                timestamp tomography_setting_t  \
# 0            552668721563158  2025-07-03--15h-45m-02s                    H
# 1            552883897914105  2025-07-03--15h-45m-35s                    V
# 2            552989482045603  2025-07-03--15h-45m-51s                    V
# 3            552989482325354  2025-07-03--15h-45m-51s                    V
# 4            552989482855132  2025-07-03--15h-45m-51s                    V
# ...                      ...                      ...                  ...
# 1691021 -4242167945972078080  2025-07-08--11h-07m-44s                    V
# 1691022 -4242168163956942336  2025-07-08--11h-07m-10s                    H
# 1691023 -4242168163956753920  2025-07-08--11h-07m-11s                    H
# 1691024 -4242168054817446400  2025-07-08--11h-07m-28s                    H
# 1691025 -4242168054816606720  2025-07-08--11h-07m-27s                    H
#
#         tomography_setting_r                 data_dir estimation_label  \
# 0                          H  2025-07-03--15h-44m-51s             DB_H
# 1                          V  2025-07-03--15h-44m-51s             DB_H
# 2                          H  2025-07-03--15h-44m-51s             DB_H
# 3                          H  2025-07-03--15h-44m-51s             DB_H
# 4                          H  2025-07-03--15h-44m-51s             DB_H
# ...                      ...                      ...              ...
# 1691021                    V  2025-07-08--11h-06m-45s                C
# 1691022                    H  2025-07-08--11h-06m-45s             DB_H
# 1691023                    H  2025-07-08--11h-06m-45s                C
# 1691024                    V  2025-07-08--11h-06m-45s                C
# 1691025                    V  2025-07-08--11h-06m-45s             DB_H
#
#         corrected_estimation_label  relative_time_tag
# 0                               HH                  0
# 1                               HH                  0
# 2                               HH                  0
# 3                               HH             279748
# 4                               HH             809529
# ...                            ...                ...
# 1691021                         C'        12778226176
# 1691022                         HH        12778231808
# 1691023                         C'        12778420224
# 1691024                         C'        12778452480
# 1691025                         HH        12779292160
#
# [1691026 rows x 11 columns]

# %% [markdown]
# # Chunk into groups of 40

# %%
# group every 40 coincidences together
coincidences_df["group"] = (coincidences_df.index // 40) + 1
coincidences_df = coincidences_df.sort_values(by=["data_dir", "group", "relative_time_tag"])
coincidences_df = coincidences_df.reset_index(drop=True)
coincidences_df
# Out:
#          detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                      9               12      552668721563163
# 1                     10               11      552883897914109
# 2                     10               11      552989482045607
# 3                      1                4      552989482325355
# 4                     10               11      552989482855136
# ...                  ...              ...                  ...
# 1691021                4               10 -4242167945972078080
# 1691022                1                4 -4242168163956942336
# 1691023                2                9 -4242168163956753920
# 1691024                7               10 -4242168054817446400
# 1691025                9               12 -4242168054816606720
#
#          detector_b_time_tag                timestamp tomography_setting_t  \
# 0            552668721563158  2025-07-03--15h-45m-02s                    H
# 1            552883897914105  2025-07-03--15h-45m-35s                    V
# 2            552989482045603  2025-07-03--15h-45m-51s                    V
# 3            552989482325354  2025-07-03--15h-45m-51s                    V
# 4            552989482855132  2025-07-03--15h-45m-51s                    V
# ...                      ...                      ...                  ...
# 1691021 -4242167945972078080  2025-07-08--11h-07m-44s                    V
# 1691022 -4242168163956942336  2025-07-08--11h-07m-10s                    H
# 1691023 -4242168163956753920  2025-07-08--11h-07m-11s                    H
# 1691024 -4242168054817446400  2025-07-08--11h-07m-28s                    H
# 1691025 -4242168054816606720  2025-07-08--11h-07m-27s                    H
#
#         tomography_setting_r                 data_dir estimation_label  \
# 0                          H  2025-07-03--15h-44m-51s             DB_H
# 1                          V  2025-07-03--15h-44m-51s             DB_H
# 2                          H  2025-07-03--15h-44m-51s             DB_H
# 3                          H  2025-07-03--15h-44m-51s             DB_H
# 4                          H  2025-07-03--15h-44m-51s             DB_H
# ...                      ...                      ...              ...
# 1691021                    V  2025-07-08--11h-06m-45s                C
# 1691022                    H  2025-07-08--11h-06m-45s             DB_H
# 1691023                    H  2025-07-08--11h-06m-45s                C
# 1691024                    V  2025-07-08--11h-06m-45s                C
# 1691025                    V  2025-07-08--11h-06m-45s             DB_H
#
#         corrected_estimation_label  relative_time_tag  group
# 0                               HH                  0      1
# 1                               HH                  0      1
# 2                               HH                  0      1
# 3                               HH             279748      1
# 4                               HH             809529      1
# ...                            ...                ...    ...
# 1691021                         C'        12778226176  42276
# 1691022                         HH        12778231808  42276
# 1691023                         C'        12778420224  42276
# 1691024                         C'        12778452480  42276
# 1691025                         HH        12779292160  42276
#
# [1691026 rows x 12 columns]

# %%
# Sum by estimation_label within each group
grouped_coincidences = coincidences_df.groupby(
    ["data_dir", "group", "estimation_label"]
).agg(
    {
        "relative_time_tag": "min",
        "detector_a_time_tag": "count"
    }
).reset_index()

# pivot the estimation_label to columns
grouped_coincidences = grouped_coincidences.pivot_table(
    index=["data_dir", "group",],
    columns="estimation_label",
    values="detector_a_time_tag",
    fill_value=0
).reset_index()
grouped_coincidences.columns.name = None 
# ensure the columns all exist
for label in ["C", "SB", "DB_V"]:
    if label not in grouped_coincidences.columns:
        grouped_coincidences[label] = 0
grouped_coincidences["N"] = grouped_coincidences["C"] + grouped_coincidences["SB"] + grouped_coincidences["DB_V"] + grouped_coincidences["DB_H"]
grouped_coincidences = grouped_coincidences[grouped_coincidences["N"] == 40].drop(columns=["group"])
grouped_coincidences
# Out:
#                       data_dir     C  DB_H  DB_V   SB     N
# 0      2025-07-03--15h-44m-51s   3.0  37.0   0.0  0.0  40.0
# 1      2025-07-03--15h-44m-51s   0.0  40.0   0.0  0.0  40.0
# 2      2025-07-03--15h-44m-51s   1.0  39.0   0.0  0.0  40.0
# 3      2025-07-03--15h-44m-51s   0.0  40.0   0.0  0.0  40.0
# 4      2025-07-03--15h-44m-51s   0.0  40.0   0.0  0.0  40.0
# ...                        ...   ...   ...   ...  ...   ...
# 42292  2025-07-08--11h-06m-45s   8.0  30.0   1.0  1.0  40.0
# 42293  2025-07-08--11h-06m-45s   7.0  30.0   1.0  2.0  40.0
# 42294  2025-07-08--11h-06m-45s  11.0  27.0   2.0  0.0  40.0
# 42295  2025-07-08--11h-06m-45s   6.0  33.0   0.0  1.0  40.0
# 42296  2025-07-08--11h-06m-45s   5.0  31.0   2.0  2.0  40.0
#
# [42253 rows x 6 columns]

# %%
from concurrent.futures import ThreadPoolExecutor

grouped = dict(tuple(grouped_coincidences.groupby("data_dir")))

def save_group(data_dir):
    df_subset = grouped[data_dir]
    output_file = os.path.join(data_folder, data_dir, "chunked_coincidences_n=40.csv")
    df_subset.to_csv(output_file, index=False)
    print(f"Saved {output_file}")

with ThreadPoolExecutor(max_workers=8) as executor:
    executor.map(save_group, new_data_dirs)
# Out:
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/chunked_coincidences_n=40.csvSaved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/chunked_coincidences_n=40.csv
#
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/chunked_coincidences_n=40.csv

# %% [markdown]
# ## Using the corrected labels

# %%
# Sum by estimation_label within each group
grouped_corrected_coincidences = coincidences_df.groupby(
    ["data_dir", "group", "corrected_estimation_label"]
).agg(
    {
        "relative_time_tag": "min",
        "detector_a_time_tag": "count"
    }
).reset_index()

# pivot the estimation_label to columns
grouped_corrected_coincidences = grouped_corrected_coincidences.pivot_table(
    index=["data_dir", "group",],
    columns="corrected_estimation_label",
    values="detector_a_time_tag",
    fill_value=0
).reset_index()
grouped_corrected_coincidences.columns.name = None 
# ensure the columns all exist
for label in ["C'", "SB", "HH", "VV"]:
    if label not in grouped_corrected_coincidences.columns:
        grouped_corrected_coincidences[label] = 0
grouped_corrected_coincidences["N"] = grouped_corrected_coincidences["C'"] + grouped_corrected_coincidences["SB"] + grouped_corrected_coincidences["HH"] + grouped_corrected_coincidences["VV"]
grouped_corrected_coincidences = grouped_corrected_coincidences[grouped_corrected_coincidences["N"] == 40].drop(columns=["group"])
grouped_corrected_coincidences
# Out:
#                       data_dir    C'    HH   SB   VV     N
# 0      2025-07-03--15h-44m-51s   1.0  39.0  0.0  0.0  40.0
# 1      2025-07-03--15h-44m-51s   0.0  40.0  0.0  0.0  40.0
# 2      2025-07-03--15h-44m-51s   0.0  40.0  0.0  0.0  40.0
# 3      2025-07-03--15h-44m-51s   0.0  40.0  0.0  0.0  40.0
# 4      2025-07-03--15h-44m-51s   0.0  40.0  0.0  0.0  40.0
# ...                        ...   ...   ...  ...  ...   ...
# 42292  2025-07-08--11h-06m-45s   5.0  33.0  1.0  1.0  40.0
# 42293  2025-07-08--11h-06m-45s   6.0  31.0  2.0  1.0  40.0
# 42294  2025-07-08--11h-06m-45s  10.0  28.0  0.0  2.0  40.0
# 42295  2025-07-08--11h-06m-45s   6.0  33.0  1.0  0.0  40.0
# 42296  2025-07-08--11h-06m-45s   5.0  31.0  2.0  2.0  40.0
#
# [42253 rows x 6 columns]

# %%
grouped = dict(tuple(grouped_corrected_coincidences.groupby("data_dir")))

def save_group(data_dir):
    df_subset = grouped[data_dir]
    output_file = os.path.join(data_folder, data_dir, "corrected_chunked_coincidences_n=40.csv")
    df_subset.to_csv(output_file, index=False)
    print(f"Saved {output_file}")

with ThreadPoolExecutor(max_workers=8) as executor:
    executor.map(save_group, new_data_dirs)
# Out:
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/corrected_chunked_coincidences_n=40.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/corrected_chunked_coincidences_n=40.csv

# %% [markdown]
# # Create higher n estimates

# %%
grouped_coincidences["group_80"] = (grouped_coincidences.index // 2) + 1
grouped_coincidences["group_120"] = (grouped_coincidences.index // 3) + 1
grouped_coincidences["group_160"] = (grouped_coincidences.index // 4) + 1
grouped_coincidences["group_200"] = (grouped_coincidences.index // 5) + 1

# sum by group_80, group_120, group_160, group_200
grouped_coincidences_80 = grouped_coincidences.groupby(
    ["data_dir", "group_80"]
).agg(
    {
        "C": "sum",
        "SB": "sum",
        "DB_V": "sum",
        "DB_H": "sum",
        "N": "sum"
    }
).reset_index()

grouped_coincidences_120 = grouped_coincidences.groupby(
    ["data_dir", "group_120"]
).agg(
    {
        "C": "sum",
        "SB": "sum",
        "DB_V": "sum",
        "DB_H": "sum",
        "N": "sum"
    }
).reset_index()

grouped_coincidences_160 = grouped_coincidences.groupby(
    ["data_dir", "group_160"]
).agg(
    {
        "C": "sum",
        "SB": "sum",
        "DB_V": "sum",
        "DB_H": "sum",
        "N": "sum"
    }
).reset_index()

grouped_coincidences_200 = grouped_coincidences.groupby(
    ["data_dir", "group_200"]
).agg(
    {
        "C": "sum",
        "SB": "sum",
        "DB_V": "sum",
        "DB_H": "sum",
        "N": "sum"
    }
).reset_index()

grouped_coincidences_80 = grouped_coincidences_80[grouped_coincidences_80["N"] == 80].drop(columns=["group_80"])
grouped_coincidences_120 = grouped_coincidences_120[grouped_coincidences_120["N"] == 120].drop(columns=["group_120"])
grouped_coincidences_160 = grouped_coincidences_160[grouped_coincidences_160["N"] == 160].drop(columns=["group_160"])
grouped_coincidences_200 = grouped_coincidences_200[grouped_coincidences_200["N"] == 200].drop(columns=["group_200"])

grouped_coincidences_200
# Out:
#                      data_dir     C    SB  DB_V   DB_H      N
# 0     2025-07-03--15h-44m-51s   4.0   0.0   0.0  196.0  200.0
# 1     2025-07-03--15h-44m-51s   1.0   0.0   0.0  199.0  200.0
# 2     2025-07-03--15h-44m-51s   1.0   0.0   0.0  199.0  200.0
# 3     2025-07-03--15h-44m-51s   4.0   0.0   0.0  196.0  200.0
# 4     2025-07-03--15h-44m-51s   3.0   0.0   0.0  197.0  200.0
# ...                       ...   ...   ...   ...    ...    ...
# 8460  2025-07-08--11h-06m-45s  44.0  13.0   4.0  139.0  200.0
# 8461  2025-07-08--11h-06m-45s  45.0   9.0   2.0  144.0  200.0
# 8462  2025-07-08--11h-06m-45s  51.0  11.0   5.0  133.0  200.0
# 8463  2025-07-08--11h-06m-45s  41.0  10.0   6.0  143.0  200.0
# 8464  2025-07-08--11h-06m-45s  42.0   8.0   5.0  145.0  200.0
#
# [8429 rows x 6 columns]

# %%
def save_grouped_data(df, n):
    df = df[df["N"] == n]
    grouped = dict(tuple(df.groupby("data_dir")))

    def save_group(data_dir):
        df_subset = grouped[data_dir]
        output_file = os.path.join(data_folder, data_dir, f"chunked_coincidences_n={n}.csv")
        df_subset.to_csv(output_file, index=False)
        print(f"Saved {output_file}")

    with ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(save_group, new_data_dirs)


save_grouped_data(grouped_coincidences_80, 80)
save_grouped_data(grouped_coincidences_120, 120)
save_grouped_data(grouped_coincidences_160, 160)
save_grouped_data(grouped_coincidences_200, 200)
# Out:
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/chunked_coincidences_n=200.csv

# %% [markdown]
# ## Using corrected labels

# %%
grouped_corrected_coincidences["group_80"] = (grouped_corrected_coincidences.index // 2) + 1
grouped_corrected_coincidences["group_120"] = (grouped_corrected_coincidences.index // 3) + 1
grouped_corrected_coincidences["group_160"] = (grouped_corrected_coincidences.index // 4) + 1
grouped_corrected_coincidences["group_200"] = (grouped_corrected_coincidences.index // 5) + 1

# sum by group_80, group_120, group_160, group_200
grouped_corrected_coincidences_80 = grouped_corrected_coincidences.groupby(
    ["data_dir", "group_80"]
).agg(
    {
        "C'": "sum",
        "SB": "sum",
        "VV": "sum",
        "HH": "sum",
        "N": "sum"
    }
).reset_index()

grouped_corrected_coincidences_120 = grouped_corrected_coincidences.groupby(
    ["data_dir", "group_120"]
).agg(
    {
        "C'": "sum",
        "SB": "sum",
        "VV": "sum",
        "HH": "sum",
        "N": "sum"
    }
).reset_index()

grouped_corrected_coincidences_160 = grouped_corrected_coincidences.groupby(
    ["data_dir", "group_160"]
).agg(
    {
        "C'": "sum",
        "SB": "sum",
        "VV": "sum",
        "HH": "sum",
        "N": "sum"
    }
).reset_index()

grouped_corrected_coincidences_200 = grouped_corrected_coincidences.groupby(
    ["data_dir", "group_200"]
).agg(
    {
        "C'": "sum",
        "SB": "sum",
        "VV": "sum",
        "HH": "sum",
        "N": "sum"
    }
).reset_index()

grouped_corrected_coincidences_80 = grouped_corrected_coincidences_80[grouped_corrected_coincidences_80["N"] == 80].drop(columns=["group_80"])
grouped_corrected_coincidences_120 = grouped_corrected_coincidences_120[grouped_corrected_coincidences_120["N"] == 120].drop(columns=["group_120"])
grouped_corrected_coincidences_160 = grouped_corrected_coincidences_160[grouped_corrected_coincidences_160["N"] == 160].drop(columns=["group_160"])
grouped_corrected_coincidences_200 = grouped_corrected_coincidences_200[grouped_corrected_coincidences_200["N"] == 200].drop(columns=["group_200"])

grouped_corrected_coincidences_200
# Out:
#                      data_dir    C'    SB   VV     HH      N
# 0     2025-07-03--15h-44m-51s   1.0   0.0  0.0  199.0  200.0
# 1     2025-07-03--15h-44m-51s   0.0   0.0  0.0  200.0  200.0
# 2     2025-07-03--15h-44m-51s   0.0   0.0  0.0  200.0  200.0
# 3     2025-07-03--15h-44m-51s   0.0   0.0  0.0  200.0  200.0
# 4     2025-07-03--15h-44m-51s   0.0   0.0  0.0  200.0  200.0
# ...                       ...   ...   ...  ...    ...    ...
# 8460  2025-07-08--11h-06m-45s  35.0  13.0  4.0  148.0  200.0
# 8461  2025-07-08--11h-06m-45s  38.0   9.0  2.0  151.0  200.0
# 8462  2025-07-08--11h-06m-45s  39.0  11.0  5.0  145.0  200.0
# 8463  2025-07-08--11h-06m-45s  40.0  10.0  6.0  144.0  200.0
# 8464  2025-07-08--11h-06m-45s  36.0   8.0  5.0  151.0  200.0
#
# [8429 rows x 6 columns]

# %%
def save_grouped_data(df, n):
    df = df[df["N"] == n]
    grouped = dict(tuple(df.groupby("data_dir")))

    def save_group(data_dir):
        df_subset = grouped[data_dir]
        output_file = os.path.join(data_folder, data_dir, f"corrected_chunked_coincidences_n={n}.csv")
        df_subset.to_csv(output_file, index=False)
        print(f"Saved {output_file}")

    with ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(save_group, new_data_dirs)


save_grouped_data(grouped_corrected_coincidences_80, 80)
save_grouped_data(grouped_corrected_coincidences_120, 120)
save_grouped_data(grouped_corrected_coincidences_160, 160)
save_grouped_data(grouped_corrected_coincidences_200, 200)
# Out:
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/corrected_chunked_coincidences_n=80.csvSaved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/corrected_chunked_coincidences_n=80.csv
#
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/corrected_chunked_coincidences_n=80.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/corrected_chunked_coincidences_n=120.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/corrected_chunked_coincidences_n=160.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--15h-44m-51s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-11m-36s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-22m-15s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-27m-19s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-16m-56s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-36m-39s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--11h-59m-57s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-12m-21s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-03--16h-42m-17s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-05m-34s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-51m-58s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-37m-06s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--12h-19m-57s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-31m-04s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-45m-36s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-07--14h-57m-39s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-40m-12s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-30m-07s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-56m-10s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-45m-36s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-01m-30s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--10h-35m-04s/corrected_chunked_coincidences_n=200.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-07-08--11h-06m-45s/corrected_chunked_coincidences_n=200.csv
