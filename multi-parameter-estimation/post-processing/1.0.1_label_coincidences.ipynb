# %%
import pandas as pd
import numpy as np
import os

# %%
# White and blue output ports of the in-fibre beam splitters
DETECTORS = {
    9: {"arm": "TT", "color": "white"},
    12: {"arm": "TT", "color": "blue"},
    11: {"arm": "TR", "color": "white"},
    10: {"arm": "TR", "color": "blue"},
    1: {"arm": "RT", "color": "white"},
    4: {"arm": "RT", "color": "blue"},
    7: {"arm": "RR", "color": "white"},
    2: {"arm": "RR", "color": "blue"},
}

# %%
# Set to True to force a full refresh of the data
full_refresh = True

# %%
repo_root = os.popen('git rev-parse --show-toplevel').read().strip()

# %%
data_folder = os.path.join(repo_root, 'multi-parameter-estimation', 'data')

# Get list of data directories
data_dirs = os.listdir(data_folder)
data_dirs = [d for d in data_dirs if os.path.isdir(os.path.join(data_folder, d))]

# skip old-data
if 'old-data' in data_dirs:
    data_dirs.remove('old-data')

data_dirs.sort()
data_dirs
# Out:
# ['2025-06-20--17h-16m-34s',
#  '2025-06-20--17h-21m-29s',
#  '2025-06-20--17h-26m-32s',
#  '2025-06-20--17h-31m-35s',
#  '2025-06-20--17h-36m-38s',
#  '2025-06-20--17h-41m-43s',
#  '2025-06-20--17h-46m-48s',
#  '2025-06-20--17h-51m-53s',
#  '2025-06-20--17h-56m-58s',
#  '2025-06-20--18h-02m-03s',
#  '2025-06-20--18h-07m-08s',
#  '2025-06-20--18h-12m-13s',
#  '2025-06-20--18h-17m-18s',
#  '2025-06-20--18h-22m-24s',
#  '2025-06-20--18h-27m-28s',
#  '2025-06-20--18h-32m-32s',
#  '2025-06-20--18h-37m-37s',
#  '2025-06-20--18h-42m-41s',
#  '2025-06-20--18h-47m-44s',
#  '2025-06-20--18h-52m-47s',
#  '2025-06-20--18h-57m-50s',
#  '2025-06-20--19h-02m-55s',
#  '2025-06-20--19h-08m-00s',
#  '2025-06-20--19h-13m-05s',
#  '2025-06-20--19h-18m-11s',
#  '2025-06-20--19h-23m-16s',
#  '2025-06-20--19h-28m-37s',
#  '2025-06-20--19h-33m-42s',
#  '2025-06-20--19h-38m-47s',
#  '2025-06-20--19h-43m-53s',
#  '2025-06-20--19h-48m-57s',
#  '2025-06-20--19h-54m-03s',
#  '2025-06-20--19h-59m-08s',
#  '2025-06-20--20h-04m-13s',
#  '2025-06-20--20h-09m-20s',
#  '2025-06-20--20h-14m-26s',
#  '2025-06-20--20h-19m-32s',
#  '2025-06-20--20h-24m-38s',
#  '2025-06-20--20h-29m-43s',
#  '2025-06-20--20h-34m-49s',
#  '2025-06-20--20h-39m-53s',
#  '2025-06-20--20h-44m-58s',
#  '2025-06-20--20h-50m-03s',
#  '2025-06-20--20h-55m-09s',
#  '2025-06-20--21h-00m-16s',
#  '2025-06-20--21h-05m-21s',
#  '2025-06-20--21h-10m-26s',
#  '2025-06-20--21h-15m-31s',
#  '2025-06-20--21h-20m-36s',
#  '2025-06-20--21h-25m-41s',
#  '2025-06-20--21h-30m-46s',
#  '2025-06-20--21h-36m-06s',
#  '2025-06-20--21h-41m-13s',
#  '2025-06-20--21h-46m-17s',
#  '2025-06-20--21h-51m-22s',
#  '2025-06-20--21h-56m-29s',
#  '2025-06-20--22h-01m-34s',
#  '2025-06-20--22h-06m-40s',
#  '2025-06-20--22h-11m-45s',
#  '2025-06-20--22h-16m-51s',
#  '2025-06-20--22h-21m-55s',
#  '2025-06-20--22h-27m-02s',
#  '2025-06-20--22h-32m-08s',
#  '2025-06-20--22h-37m-12s',
#  '2025-06-20--22h-42m-17s',
#  '2025-06-20--22h-47m-22s',
#  '2025-06-20--22h-52m-27s',
#  '2025-06-20--22h-57m-32s',
#  '2025-06-20--23h-02m-38s',
#  '2025-06-20--23h-07m-45s',
#  '2025-06-20--23h-12m-49s',
#  '2025-06-20--23h-17m-54s',
#  '2025-06-20--23h-22m-59s',
#  '2025-06-20--23h-28m-04s',
#  '2025-06-20--23h-33m-09s',
#  '2025-06-20--23h-38m-14s',
#  '2025-06-20--23h-43m-38s',
#  '2025-06-20--23h-48m-43s',
#  '2025-06-20--23h-53m-46s',
#  '2025-06-20--23h-58m-51s',
#  '2025-06-21--00h-03m-54s',
#  '2025-06-21--00h-08m-58s',
#  '2025-06-21--00h-14m-03s',
#  '2025-06-21--00h-19m-08s',
#  '2025-06-21--00h-24m-12s',
#  '2025-06-21--00h-29m-16s',
#  '2025-06-21--00h-34m-20s',
#  '2025-06-21--00h-39m-26s',
#  '2025-06-21--00h-44m-33s',
#  '2025-06-21--00h-49m-38s',
#  '2025-06-21--00h-54m-42s',
#  '2025-06-21--00h-59m-48s',
#  '2025-06-21--01h-04m-52s',
#  '2025-06-21--01h-09m-57s',
#  '2025-06-21--01h-15m-03s',
#  '2025-06-21--01h-20m-08s',
#  '2025-06-21--01h-25m-14s',
#  '2025-06-21--01h-30m-18s',
#  '2025-06-21--01h-35m-23s',
#  '2025-06-21--01h-40m-28s',
#  '2025-06-21--01h-45m-32s',
#  '2025-06-21--01h-50m-47s',
#  '2025-06-21--01h-55m-52s',
#  '2025-06-21--02h-00m-57s',
#  '2025-06-21--02h-06m-01s',
#  '2025-06-21--02h-11m-06s',
#  '2025-06-21--02h-16m-10s',
#  '2025-06-21--02h-21m-15s',
#  '2025-06-21--02h-26m-20s',
#  '2025-06-21--02h-31m-26s',
#  '2025-06-21--02h-36m-31s',
#  '2025-06-21--02h-41m-38s',
#  '2025-06-21--02h-46m-44s',
#  '2025-06-21--02h-51m-48s',
#  '2025-06-21--02h-56m-55s',
#  '2025-06-21--03h-01m-58s',
#  '2025-06-21--03h-07m-03s',
#  '2025-06-21--03h-12m-07s',
#  '2025-06-21--03h-17m-12s',
#  '2025-06-21--03h-22m-31s',
#  '2025-06-21--03h-27m-36s',
#  '2025-06-21--03h-32m-41s',
#  '2025-06-21--03h-37m-46s',
#  '2025-06-21--03h-42m-51s',
#  '2025-06-21--03h-47m-55s']

# %%
new_data_dirs = data_dirs.copy()

if not full_refresh:
    for d in data_dirs:
        if os.path.exists(os.path.join(data_folder, d, "scaled_coincidences.csv")):
            new_data_dirs.remove(d)

new_data_dirs
# Out:
# ['2025-06-20--17h-16m-34s',
#  '2025-06-20--17h-21m-29s',
#  '2025-06-20--17h-26m-32s',
#  '2025-06-20--17h-31m-35s',
#  '2025-06-20--17h-36m-38s',
#  '2025-06-20--17h-41m-43s',
#  '2025-06-20--17h-46m-48s',
#  '2025-06-20--17h-51m-53s',
#  '2025-06-20--17h-56m-58s',
#  '2025-06-20--18h-02m-03s',
#  '2025-06-20--18h-07m-08s',
#  '2025-06-20--18h-12m-13s',
#  '2025-06-20--18h-17m-18s',
#  '2025-06-20--18h-22m-24s',
#  '2025-06-20--18h-27m-28s',
#  '2025-06-20--18h-32m-32s',
#  '2025-06-20--18h-37m-37s',
#  '2025-06-20--18h-42m-41s',
#  '2025-06-20--18h-47m-44s',
#  '2025-06-20--18h-52m-47s',
#  '2025-06-20--18h-57m-50s',
#  '2025-06-20--19h-02m-55s',
#  '2025-06-20--19h-08m-00s',
#  '2025-06-20--19h-13m-05s',
#  '2025-06-20--19h-18m-11s',
#  '2025-06-20--19h-23m-16s',
#  '2025-06-20--19h-28m-37s',
#  '2025-06-20--19h-33m-42s',
#  '2025-06-20--19h-38m-47s',
#  '2025-06-20--19h-43m-53s',
#  '2025-06-20--19h-48m-57s',
#  '2025-06-20--19h-54m-03s',
#  '2025-06-20--19h-59m-08s',
#  '2025-06-20--20h-04m-13s',
#  '2025-06-20--20h-09m-20s',
#  '2025-06-20--20h-14m-26s',
#  '2025-06-20--20h-19m-32s',
#  '2025-06-20--20h-24m-38s',
#  '2025-06-20--20h-29m-43s',
#  '2025-06-20--20h-34m-49s',
#  '2025-06-20--20h-39m-53s',
#  '2025-06-20--20h-44m-58s',
#  '2025-06-20--20h-50m-03s',
#  '2025-06-20--20h-55m-09s',
#  '2025-06-20--21h-00m-16s',
#  '2025-06-20--21h-05m-21s',
#  '2025-06-20--21h-10m-26s',
#  '2025-06-20--21h-15m-31s',
#  '2025-06-20--21h-20m-36s',
#  '2025-06-20--21h-25m-41s',
#  '2025-06-20--21h-30m-46s',
#  '2025-06-20--21h-36m-06s',
#  '2025-06-20--21h-41m-13s',
#  '2025-06-20--21h-46m-17s',
#  '2025-06-20--21h-51m-22s',
#  '2025-06-20--21h-56m-29s',
#  '2025-06-20--22h-01m-34s',
#  '2025-06-20--22h-06m-40s',
#  '2025-06-20--22h-11m-45s',
#  '2025-06-20--22h-16m-51s',
#  '2025-06-20--22h-21m-55s',
#  '2025-06-20--22h-27m-02s',
#  '2025-06-20--22h-32m-08s',
#  '2025-06-20--22h-37m-12s',
#  '2025-06-20--22h-42m-17s',
#  '2025-06-20--22h-47m-22s',
#  '2025-06-20--22h-52m-27s',
#  '2025-06-20--22h-57m-32s',
#  '2025-06-20--23h-02m-38s',
#  '2025-06-20--23h-07m-45s',
#  '2025-06-20--23h-12m-49s',
#  '2025-06-20--23h-17m-54s',
#  '2025-06-20--23h-22m-59s',
#  '2025-06-20--23h-28m-04s',
#  '2025-06-20--23h-33m-09s',
#  '2025-06-20--23h-38m-14s',
#  '2025-06-20--23h-43m-38s',
#  '2025-06-20--23h-48m-43s',
#  '2025-06-20--23h-53m-46s',
#  '2025-06-20--23h-58m-51s',
#  '2025-06-21--00h-03m-54s',
#  '2025-06-21--00h-08m-58s',
#  '2025-06-21--00h-14m-03s',
#  '2025-06-21--00h-19m-08s',
#  '2025-06-21--00h-24m-12s',
#  '2025-06-21--00h-29m-16s',
#  '2025-06-21--00h-34m-20s',
#  '2025-06-21--00h-39m-26s',
#  '2025-06-21--00h-44m-33s',
#  '2025-06-21--00h-49m-38s',
#  '2025-06-21--00h-54m-42s',
#  '2025-06-21--00h-59m-48s',
#  '2025-06-21--01h-04m-52s',
#  '2025-06-21--01h-09m-57s',
#  '2025-06-21--01h-15m-03s',
#  '2025-06-21--01h-20m-08s',
#  '2025-06-21--01h-25m-14s',
#  '2025-06-21--01h-30m-18s',
#  '2025-06-21--01h-35m-23s',
#  '2025-06-21--01h-40m-28s',
#  '2025-06-21--01h-45m-32s',
#  '2025-06-21--01h-50m-47s',
#  '2025-06-21--01h-55m-52s',
#  '2025-06-21--02h-00m-57s',
#  '2025-06-21--02h-06m-01s',
#  '2025-06-21--02h-11m-06s',
#  '2025-06-21--02h-16m-10s',
#  '2025-06-21--02h-21m-15s',
#  '2025-06-21--02h-26m-20s',
#  '2025-06-21--02h-31m-26s',
#  '2025-06-21--02h-36m-31s',
#  '2025-06-21--02h-41m-38s',
#  '2025-06-21--02h-46m-44s',
#  '2025-06-21--02h-51m-48s',
#  '2025-06-21--02h-56m-55s',
#  '2025-06-21--03h-01m-58s',
#  '2025-06-21--03h-07m-03s',
#  '2025-06-21--03h-12m-07s',
#  '2025-06-21--03h-17m-12s',
#  '2025-06-21--03h-22m-31s',
#  '2025-06-21--03h-27m-36s',
#  '2025-06-21--03h-32m-41s',
#  '2025-06-21--03h-37m-46s',
#  '2025-06-21--03h-42m-51s',
#  '2025-06-21--03h-47m-55s']

# %%
def load_coincidences(data_dir):
    coincidences = pd.read_csv(os.path.join(data_folder, data_dir, "coincidences.csv"))
    coincidences["data_dir"] = data_dir
    return coincidences

coincidences_df = pd.concat([load_coincidences(d) for d in new_data_dirs], ignore_index=True)
coincidences_df
# Out:
#           detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                       1                4  2555412465261692416
# 1                       1                4  2555412465265911296
# 2                       9               12  2555412465267243520
# 3                       9               12  2555412465268338688
# 4                       9               12  2555412465269690880
# ...                   ...              ...                  ...
# 56614731                1                7  2557399189369489920
# 56614732                4                9  2557399189370192896
# 56614733                9               12  2557399189372173824
# 56614734                4                9  2557399189376884224
# 56614735                4                9  2557399189377887744
#
#           detector_b_time_tag                timestamp tomography_setting_t  \
# 0         2555412465261692416  2025-06-20--17h-17m-43s                    H
# 1         2555412465265911296  2025-06-20--17h-17m-43s                    H
# 2         2555412465267243520  2025-06-20--17h-17m-42s                    H
# 3         2555412465268338688  2025-06-20--17h-17m-42s                    H
# 4         2555412465269690880  2025-06-20--17h-17m-42s                    H
# ...                       ...                      ...                  ...
# 56614731  2557399189369489920  2025-06-21--03h-52m-59s                    V
# 56614732  2557399189370192896  2025-06-21--03h-52m-59s                    V
# 56614733  2557399189372173824  2025-06-21--03h-52m-59s                    V
# 56614734  2557399189376884224  2025-06-21--03h-52m-59s                    V
# 56614735  2557399189377887744  2025-06-21--03h-52m-59s                    V
#
#          tomography_setting_r                 data_dir
# 0                           H  2025-06-20--17h-16m-34s
# 1                           H  2025-06-20--17h-16m-34s
# 2                           H  2025-06-20--17h-16m-34s
# 3                           H  2025-06-20--17h-16m-34s
# 4                           H  2025-06-20--17h-16m-34s
# ...                       ...                      ...
# 56614731                    H  2025-06-21--03h-47m-55s
# 56614732                    H  2025-06-21--03h-47m-55s
# 56614733                    H  2025-06-21--03h-47m-55s
# 56614734                    H  2025-06-21--03h-47m-55s
# 56614735                    H  2025-06-21--03h-47m-55s
#
# [56614736 rows x 8 columns]

# %%
# drop estimation label if it exists
if "estimation_label" in coincidences_df.columns:
    coincidences_df = coincidences_df.drop(columns=["estimation_label"])
coincidences_df
# Out:
#           detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                       1                4  2555412465261692416
# 1                       1                4  2555412465265911296
# 2                       9               12  2555412465267243520
# 3                       9               12  2555412465268338688
# 4                       9               12  2555412465269690880
# ...                   ...              ...                  ...
# 56614731                1                7  2557399189369489920
# 56614732                4                9  2557399189370192896
# 56614733                9               12  2557399189372173824
# 56614734                4                9  2557399189376884224
# 56614735                4                9  2557399189377887744
#
#           detector_b_time_tag                timestamp tomography_setting_t  \
# 0         2555412465261692416  2025-06-20--17h-17m-43s                    H
# 1         2555412465265911296  2025-06-20--17h-17m-43s                    H
# 2         2555412465267243520  2025-06-20--17h-17m-42s                    H
# 3         2555412465268338688  2025-06-20--17h-17m-42s                    H
# 4         2555412465269690880  2025-06-20--17h-17m-42s                    H
# ...                       ...                      ...                  ...
# 56614731  2557399189369489920  2025-06-21--03h-52m-59s                    V
# 56614732  2557399189370192896  2025-06-21--03h-52m-59s                    V
# 56614733  2557399189372173824  2025-06-21--03h-52m-59s                    V
# 56614734  2557399189376884224  2025-06-21--03h-52m-59s                    V
# 56614735  2557399189377887744  2025-06-21--03h-52m-59s                    V
#
#          tomography_setting_r                 data_dir
# 0                           H  2025-06-20--17h-16m-34s
# 1                           H  2025-06-20--17h-16m-34s
# 2                           H  2025-06-20--17h-16m-34s
# 3                           H  2025-06-20--17h-16m-34s
# 4                           H  2025-06-20--17h-16m-34s
# ...                       ...                      ...
# 56614731                    H  2025-06-21--03h-47m-55s
# 56614732                    H  2025-06-21--03h-47m-55s
# 56614733                    H  2025-06-21--03h-47m-55s
# 56614734                    H  2025-06-21--03h-47m-55s
# 56614735                    H  2025-06-21--03h-47m-55s
#
# [56614736 rows x 8 columns]

# %%
def get_effective_detector_label(arm, tomography_setting_a, tomography_setting_b):
    arm = list(arm)
    # If the arm is T and the tomography a setting is V, then flip the detector 
    if arm[0] == "T" and tomography_setting_a == "V":
        arm[1] = "T" if arm[1] == "R" else "R"
    # If the arm is R and the tomography b setting is V, then flip the detector
    if arm[0] == "R" and tomography_setting_b == "V":
        arm[1] = "T" if arm[1] == "R" else "R"
    return "".join(arm)


def get_estimation_label(arm_a, arm_b, tomography_setting_a, tomography_setting_b):
    # If the tomo is in V, then the detectors are effectively flipped in that arm
    arm_a = get_effective_detector_label(arm_a, tomography_setting_a, tomography_setting_b)
    arm_b = get_effective_detector_label(arm_b, tomography_setting_a, tomography_setting_b)
    
    # Double bunched
    if arm_a == arm_b:
        # DB_H
        if arm_a[1] == "T":
            return "DB_H"
        # DB_V
        elif arm_a[1] == "R":
            return "DB_V"
        else:
            raise ValueError(f"Unknown arm: {arm_a}")
    # Coincidence
    elif arm_a[0] != arm_b[0]:
        return "C"
    # Single bunched
    elif arm_a[1] != arm_b[1]:
        return "SB"
    else:
        raise ValueError(f"Unknown arm combination: {arm_a}, {arm_b}")

# %%
# Based on the imperfect indistinguishability
def get_corrected_estimation_label(arm_a, arm_b, tomography_setting_a, tomography_setting_b):
    # If the tomo is in V, then the detectors are effectively flipped in that arm
    arm_a = get_effective_detector_label(arm_a, tomography_setting_a, tomography_setting_b)
    arm_b = get_effective_detector_label(arm_b, tomography_setting_a, tomography_setting_b)
    
    # HH
    if arm_a[1] == "T" and arm_b[1] == "T":
        return "HH"
    # VV
    elif arm_a[1] == "R" and arm_b[1] == "R":
        return "VV"
    # SB
    elif arm_a[0] == arm_b[0] and arm_a[1] != arm_b[1]:
        return "SB"
    # PC'
    elif arm_a[0] != arm_b[0] and arm_a[1] != arm_b[1]:
        return "C'"
    # That should be all the cases
    else:
        raise ValueError(f"Unknown arm combination: {arm_a}, {arm_b}")

# %%
labels = pd.DataFrame(
        [
            (
                i,
                j,
                tomography_setting_a,
                tomography_setting_b,
                get_estimation_label(DETECTORS[i]["arm"], DETECTORS[j]["arm"], tomography_setting_a, tomography_setting_b),
                get_corrected_estimation_label(DETECTORS[i]["arm"], DETECTORS[j]["arm"], tomography_setting_a, tomography_setting_b)
            )
            for i in DETECTORS.keys()
            for j in DETECTORS.keys()
            for tomography_setting_a in ["H", "V"]
            for tomography_setting_b in ["H", "V"]
            if i < j
        ],
        columns=[
            "detector_a_name",
            "detector_b_name",
            "tomography_setting_t",
            "tomography_setting_r",
            "estimation_label",
            "corrected_estimation_label"
        ],
    )

labels
# Out:
#      detector_a_name  detector_b_name tomography_setting_t  \
# 0                  9               12                    H
# 1                  9               12                    H
# 2                  9               12                    V
# 3                  9               12                    V
# 4                  9               11                    H
# ..               ...              ...                  ...
# 107                2                4                    V
# 108                2                7                    H
# 109                2                7                    H
# 110                2                7                    V
# 111                2                7                    V
#
#     tomography_setting_r estimation_label corrected_estimation_label
# 0                      H             DB_H                         HH
# 1                      V             DB_H                         HH
# 2                      H             DB_V                         VV
# 3                      V             DB_V                         VV
# 4                      H               SB                         SB
# ..                   ...              ...                        ...
# 107                    V               SB                         SB
# 108                    H             DB_V                         VV
# 109                    V             DB_H                         HH
# 110                    H             DB_V                         VV
# 111                    V             DB_H                         HH
#
# [112 rows x 6 columns]

# %%
# join the labels with the coincidences dataframe
coincidences_df = coincidences_df.merge(labels, on=["detector_a_name", "detector_b_name", "tomography_setting_t", "tomography_setting_r"], how="left")
coincidences_df
# Out:
#           detector_a_name  detector_b_name  detector_a_time_tag  \
# 0                       1                4  2555412465261692416
# 1                       1                4  2555412465265911296
# 2                       9               12  2555412465267243520
# 3                       9               12  2555412465268338688
# 4                       9               12  2555412465269690880
# ...                   ...              ...                  ...
# 56614731                1                7  2557399189369489920
# 56614732                4                9  2557399189370192896
# 56614733                9               12  2557399189372173824
# 56614734                4                9  2557399189376884224
# 56614735                4                9  2557399189377887744
#
#           detector_b_time_tag                timestamp tomography_setting_t  \
# 0         2555412465261692416  2025-06-20--17h-17m-43s                    H
# 1         2555412465265911296  2025-06-20--17h-17m-43s                    H
# 2         2555412465267243520  2025-06-20--17h-17m-42s                    H
# 3         2555412465268338688  2025-06-20--17h-17m-42s                    H
# 4         2555412465269690880  2025-06-20--17h-17m-42s                    H
# ...                       ...                      ...                  ...
# 56614731  2557399189369489920  2025-06-21--03h-52m-59s                    V
# 56614732  2557399189370192896  2025-06-21--03h-52m-59s                    V
# 56614733  2557399189372173824  2025-06-21--03h-52m-59s                    V
# 56614734  2557399189376884224  2025-06-21--03h-52m-59s                    V
# 56614735  2557399189377887744  2025-06-21--03h-52m-59s                    V
#
#          tomography_setting_r                 data_dir estimation_label  \
# 0                           H  2025-06-20--17h-16m-34s             DB_H
# 1                           H  2025-06-20--17h-16m-34s             DB_H
# 2                           H  2025-06-20--17h-16m-34s             DB_H
# 3                           H  2025-06-20--17h-16m-34s             DB_H
# 4                           H  2025-06-20--17h-16m-34s             DB_H
# ...                       ...                      ...              ...
# 56614731                    H  2025-06-21--03h-47m-55s               SB
# 56614732                    H  2025-06-21--03h-47m-55s                C
# 56614733                    H  2025-06-21--03h-47m-55s             DB_V
# 56614734                    H  2025-06-21--03h-47m-55s                C
# 56614735                    H  2025-06-21--03h-47m-55s                C
#
#          corrected_estimation_label
# 0                                HH
# 1                                HH
# 2                                HH
# 3                                HH
# 4                                HH
# ...                             ...
# 56614731                         SB
# 56614732                         C'
# 56614733                         VV
# 56614734                         C'
# 56614735                         C'
#
# [56614736 rows x 10 columns]

# %%
grouped = {
    data_dir: df for data_dir, df in coincidences_df.groupby("data_dir")
}

# %%
from concurrent.futures import ProcessPoolExecutor

def save_scaled_coincidences(args):
    data_dir, df_subset = args
    if not df_subset.empty:
        output_file = os.path.join(data_folder, data_dir, "labelled_coincidences.csv")
        df_subset.to_csv(output_file, index=False)
        print(f"Saved {output_file}")

with ProcessPoolExecutor(max_workers=8) as executor:
    executor.map(save_scaled_coincidences, [(k, grouped[k]) for k in new_data_dirs])
# Out:
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-21m-29s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-16m-34s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-26m-32s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-31m-35s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-41m-43s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-36m-38s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-46m-48s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-51m-53s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--17h-56m-58s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-07m-08s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-02m-03s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-12m-13s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-17m-18s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-22m-24s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-27m-28s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-32m-32s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-37m-37s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-42m-41s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-47m-44s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-52m-47s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--18h-57m-50s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-02m-55s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-08m-00s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-13m-05s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-18m-11s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-23m-16s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-28m-37s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-33m-42s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-43m-53s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-38m-47s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-48m-57s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-54m-03s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--19h-59m-08s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-04m-13s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-19m-32s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-09m-20s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-14m-26s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-24m-38s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-29m-43s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-34m-49s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-39m-53s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-44m-58s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-55m-09s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--20h-50m-03s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-10m-26s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-05m-21s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-00m-16s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-15m-31s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-20m-36s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-25m-41s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-30m-46s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-41m-13s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-36m-06s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-46m-17s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-51m-22s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--21h-56m-29s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-01m-34s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-06m-40s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-11m-45s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-16m-51s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-21m-55s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-27m-02s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-32m-08s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-37m-12s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-42m-17s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-52m-27s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-47m-22s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-02m-38s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--22h-57m-32s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-07m-45s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-22m-59s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-17m-54s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-12m-49s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-28m-04s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-33m-09s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-38m-14s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-43m-38s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-58m-51s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-48m-43s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-20--23h-53m-46s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-03m-54s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-08m-58s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-14m-03s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-19m-08s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-24m-12s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-29m-16s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-34m-20s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-39m-26s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-44m-33s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-49m-38s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-54m-42s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--00h-59m-48s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-04m-52s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-09m-57s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-15m-03s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-20m-08s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-25m-14s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-30m-18s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-35m-23s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-40m-28s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-45m-32s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-50m-47s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--01h-55m-52s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-00m-57s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-06m-01s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-11m-06s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-16m-10s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-21m-15s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-26m-20s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-31m-26s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-36m-31s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-41m-38s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-46m-44s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-51m-48s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--02h-56m-55s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-01m-58s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-07m-03s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-12m-07s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-22m-31s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-17m-12s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-27m-36s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-32m-41s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-37m-46s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-42m-51s/labelled_coincidences.csv
# Saved /home/jh115/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/multi-parameter-estimation/data/2025-06-21--03h-47m-55s/labelled_coincidences.csv
