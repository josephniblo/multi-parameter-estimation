# %%
import pandas as pd
import numpy as np
import os

# %%
data_folder = "../data"

# Get list of data directories
data_dirs = os.listdir(data_folder)
data_dirs = [d for d in data_dirs if os.path.isdir(os.path.join(data_folder, d))]
data_dirs.sort()
data_dirs
# Out:
# ['2025-05-23--12h-20m-47s',
#  '2025-05-23--12h-20m-57s',
#  '2025-05-23--12h-21m-01s',
#  '2025-05-23--12h-21m-05s',
#  '2025-05-23--12h-21m-09s',
#  '2025-05-23--12h-21m-13s',
#  '2025-05-23--12h-21m-17s',
#  '2025-05-23--12h-21m-20s',
#  '2025-05-23--12h-21m-24s',
#  '2025-05-23--12h-21m-28s',
#  '2025-05-23--12h-21m-32s',
#  '2025-05-23--12h-21m-36s',
#  '2025-05-23--12h-21m-40s',
#  '2025-05-23--12h-21m-44s',
#  '2025-05-23--12h-21m-48s',
#  '2025-05-23--12h-21m-52s',
#  '2025-05-23--12h-21m-56s',
#  '2025-05-23--12h-22m-00s',
#  '2025-05-23--12h-22m-04s',
#  '2025-05-23--12h-22m-08s',
#  '2025-05-23--12h-22m-12s',
#  '2025-05-23--12h-22m-16s',
#  '2025-05-23--12h-22m-20s',
#  '2025-05-23--12h-22m-24s',
#  '2025-05-23--12h-22m-28s',
#  '2025-05-23--12h-22m-32s',
#  '2025-05-23--12h-22m-36s',
#  '2025-05-23--12h-22m-40s',
#  '2025-05-23--12h-22m-45s',
#  '2025-05-23--12h-22m-49s',
#  '2025-05-23--12h-22m-53s',
#  '2025-05-23--12h-22m-57s',
#  '2025-05-23--12h-23m-01s',
#  '2025-05-23--12h-23m-05s',
#  '2025-05-23--12h-23m-09s',
#  '2025-05-23--12h-23m-13s',
#  '2025-05-23--12h-23m-17s',
#  '2025-05-23--12h-23m-21s',
#  '2025-05-23--12h-23m-25s',
#  '2025-05-23--12h-23m-29s',
#  '2025-05-23--12h-23m-33s',
#  '2025-05-23--12h-23m-37s',
#  '2025-05-23--12h-23m-41s',
#  '2025-05-23--12h-23m-45s',
#  '2025-05-23--12h-23m-49s',
#  '2025-05-23--12h-23m-53s',
#  '2025-05-23--12h-23m-57s',
#  '2025-05-23--12h-24m-01s',
#  '2025-05-23--12h-24m-05s',
#  '2025-05-23--12h-24m-09s',
#  '2025-05-23--12h-24m-13s',
#  '2025-05-23--12h-24m-17s',
#  '2025-05-23--12h-24m-21s',
#  '2025-05-23--12h-24m-25s',
#  '2025-05-23--12h-24m-29s',
#  '2025-05-23--12h-24m-33s',
#  '2025-05-23--12h-24m-37s',
#  '2025-05-23--12h-24m-41s',
#  '2025-05-23--12h-24m-45s',
#  '2025-05-23--12h-24m-49s']

# %%
new_data_dirs = data_dirs.copy()
# Remove directories that already have theta_delta_phi_estimates.csv
for d in data_dirs:
    if os.path.exists(os.path.join(data_folder, d, "theta_delta_phi_estimates.csv")):
        new_data_dirs.remove(d)

new_data_dirs
# Out:
# []

# %%
def load_coincidences(data_dir):
    coincidences = pd.read_csv(os.path.join(data_folder, data_dir, "coincidences.csv"))
    coincidences["data_dir"] = data_dir
    return coincidences

coincidences_df = pd.concat([load_coincidences(d) for d in new_data_dirs], ignore_index=True)
coincidences_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       3     coincidences["data_dir"] = data_dir
#       4     return coincidences
# ----> 6 coincidences_df = pd.concat([load_coincidences(d) for d in new_data_dirs], ignore_index=True)
#       7 coincidences_df
#
# File ~/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/.venv/lib/python3.13/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/.venv/lib/python3.13/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/Heriot-Watt University Team Dropbox/RES_EPS_EMQL/projects/multi-parameter-estimation/.venv/lib/python3.13/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %% [markdown]
# Double bunched events are only resolved half of the time. Therefore, we now throw away half of all non-double-bunched events to recover the expected statistics.

# %%
coincidences_df["scaled_coincidences"] = coincidences_df["coincidences"].astype(float)

coincidences_df.loc[coincidences_df["estimation_label"] == "SB", "scaled_coincidences"] = coincidences_df.loc[coincidences_df["estimation_label"] == "SB", "coincidences"] * 0.5
coincidences_df.loc[coincidences_df["estimation_label"] == "C", "scaled_coincidences"] = coincidences_df.loc[coincidences_df["estimation_label"] == "C", "coincidences"] * 0.5

coincidences_df
# Out:
#      detector_a_name  detector_b_name arm_a arm_b color_a color_b  \
# 0                  9               12    TT    TT   white    blue
# 1                  9               11    TT    TR   white   white
# 2                  9               10    TT    TR   white    blue
# 3                 11               12    TR    TT   white    blue
# 4                 10               12    TR    TT    blue    blue
# ..               ...              ...   ...   ...     ...     ...
# 779                2               12    RR    TT    blue    blue
# 780                2               11    RR    TR    blue   white
# 781                2               10    RR    TR    blue    blue
# 782                2                4    RR    RT    blue    blue
# 783                2                7    RR    RR    blue   white
#
#           delay_a       delay_b estimation_label  coincidences  \
# 0    1.016000e-08  1.172000e-08             DB_H          1194
# 1    1.016000e-08  1.172000e-08               SB            12
# 2    1.016000e-08  1.016000e-08               SB            12
# 3    1.172000e-08  1.172000e-08               SB            15
# 4    1.016000e-08  1.172000e-08               SB            19
# ..            ...           ...              ...           ...
# 779  3.120000e-09  1.172000e-08                C             0
# 780  3.120000e-09  1.172000e-08                C             0
# 781  3.120000e-09  1.016000e-08                C           160
# 782  3.120000e-09  3.910000e-09               SB             0
# 783  3.120000e-09  3.120000e-09             DB_V          5178
#
#                     data_dir  scaled_coincidences
# 0    2025-05-23--12h-23m-01s               1194.0
# 1    2025-05-23--12h-23m-01s                  6.0
# 2    2025-05-23--12h-23m-01s                  6.0
# 3    2025-05-23--12h-23m-01s                  7.5
# 4    2025-05-23--12h-23m-01s                  9.5
# ..                       ...                  ...
# 779  2025-05-23--12h-24m-49s                  0.0
# 780  2025-05-23--12h-24m-49s                  0.0
# 781  2025-05-23--12h-24m-49s                 80.0
# 782  2025-05-23--12h-24m-49s                  0.0
# 783  2025-05-23--12h-24m-49s               5178.0
#
# [784 rows x 12 columns]

# %%
# Sum up by estimation label
df_sum = (
    coincidences_df.groupby(["data_dir", "estimation_label"])
    .agg({"scaled_coincidences": "sum"})
    .reset_index()
)
df_sum
# Out:
#                     data_dir estimation_label  scaled_coincidences
# 0    2025-05-23--12h-23m-01s                C               6559.0
# 1    2025-05-23--12h-23m-01s             DB_H               2908.0
# 2    2025-05-23--12h-23m-01s             DB_V               3974.0
# 3    2025-05-23--12h-23m-01s               SB                 38.5
# 4    2025-05-23--12h-23m-05s                C               6506.5
# ..                       ...              ...                  ...
# 107  2025-05-23--12h-24m-45s               SB                  4.0
# 108  2025-05-23--12h-24m-49s                C                254.0
# 109  2025-05-23--12h-24m-49s             DB_H                  0.0
# 110  2025-05-23--12h-24m-49s             DB_V              12878.0
# 111  2025-05-23--12h-24m-49s               SB                  4.0
#
# [112 rows x 3 columns]

# %%
df_pivoted_sum = df_sum.pivot(index='data_dir', columns='estimation_label', values='scaled_coincidences')
df_pivoted_sum = df_pivoted_sum.reset_index()  # optional, to flatten the index
df_pivoted_sum.columns.name = None  # remove the name of the columns
df_pivoted_sum
# Out:
#                    data_dir       C    DB_H     DB_V    SB
# 0   2025-05-23--12h-23m-01s  6559.0  2908.0   3974.0  38.5
# 1   2025-05-23--12h-23m-05s  6506.5  2586.0   4264.0  34.5
# 2   2025-05-23--12h-23m-09s  6430.0  2259.0   4803.0  29.0
# 3   2025-05-23--12h-23m-13s  6199.5  2013.0   5220.0  35.0
# 4   2025-05-23--12h-23m-17s  6072.5  1722.0   5613.0  37.0
# 5   2025-05-23--12h-23m-21s  5795.0  1437.0   5893.0  32.0
# 6   2025-05-23--12h-23m-25s  5548.0  1197.0   6483.0  33.0
# 7   2025-05-23--12h-23m-29s  5241.0  1008.0   6911.0  32.0
# 8   2025-05-23--12h-23m-33s  5000.0   887.0   7302.0  25.0
# 9   2025-05-23--12h-23m-37s  4641.5   718.0   7682.0  31.5
# 10  2025-05-23--12h-23m-41s  4319.5   586.0   8200.0  25.5
# 11  2025-05-23--12h-23m-45s  3984.0   503.0   8646.0  22.5
# 12  2025-05-23--12h-23m-49s  3614.5   370.0   9101.0  25.0
# 13  2025-05-23--12h-23m-53s  3337.0   287.0   9275.0  21.0
# 14  2025-05-23--12h-23m-57s  2968.0   207.0   9993.0  16.0
# 15  2025-05-23--12h-24m-01s  2513.0   168.0  10026.0  15.5
# 16  2025-05-23--12h-24m-05s  2248.5   119.0  10619.0  20.0
# 17  2025-05-23--12h-24m-09s  2019.5    78.0  11218.0  14.5
# 18  2025-05-23--12h-24m-13s  1655.5    52.0  11337.0  11.0
# 19  2025-05-23--12h-24m-17s  1374.0    27.0  11486.0  11.5
# 20  2025-05-23--12h-24m-21s  1127.0    15.0  11863.0   9.0
# 21  2025-05-23--12h-24m-25s   881.5    12.0  12207.0   7.5
# 22  2025-05-23--12h-24m-29s   723.5     4.0  12145.0   6.0
# 23  2025-05-23--12h-24m-33s   531.5     2.0  12343.0   5.0
# 24  2025-05-23--12h-24m-37s   404.0     1.0  12416.0   7.5
# 25  2025-05-23--12h-24m-41s   304.5     0.0  12357.0   4.5
# 26  2025-05-23--12h-24m-45s   254.0     0.0  12765.0   4.0
# 27  2025-05-23--12h-24m-49s   254.0     0.0  12878.0   4.0

# %%
df_pivoted_sum["N"] = df_pivoted_sum["SB"] + df_pivoted_sum["C"] + df_pivoted_sum["DB_H"] + df_pivoted_sum["DB_V"]
df_pivoted_sum
# Out:
#                    data_dir       C    DB_H     DB_V    SB        N
# 0   2025-05-23--12h-23m-01s  6559.0  2908.0   3974.0  38.5  13479.5
# 1   2025-05-23--12h-23m-05s  6506.5  2586.0   4264.0  34.5  13391.0
# 2   2025-05-23--12h-23m-09s  6430.0  2259.0   4803.0  29.0  13521.0
# 3   2025-05-23--12h-23m-13s  6199.5  2013.0   5220.0  35.0  13467.5
# 4   2025-05-23--12h-23m-17s  6072.5  1722.0   5613.0  37.0  13444.5
# 5   2025-05-23--12h-23m-21s  5795.0  1437.0   5893.0  32.0  13157.0
# 6   2025-05-23--12h-23m-25s  5548.0  1197.0   6483.0  33.0  13261.0
# 7   2025-05-23--12h-23m-29s  5241.0  1008.0   6911.0  32.0  13192.0
# 8   2025-05-23--12h-23m-33s  5000.0   887.0   7302.0  25.0  13214.0
# 9   2025-05-23--12h-23m-37s  4641.5   718.0   7682.0  31.5  13073.0
# 10  2025-05-23--12h-23m-41s  4319.5   586.0   8200.0  25.5  13131.0
# 11  2025-05-23--12h-23m-45s  3984.0   503.0   8646.0  22.5  13155.5
# 12  2025-05-23--12h-23m-49s  3614.5   370.0   9101.0  25.0  13110.5
# 13  2025-05-23--12h-23m-53s  3337.0   287.0   9275.0  21.0  12920.0
# 14  2025-05-23--12h-23m-57s  2968.0   207.0   9993.0  16.0  13184.0
# 15  2025-05-23--12h-24m-01s  2513.0   168.0  10026.0  15.5  12722.5
# 16  2025-05-23--12h-24m-05s  2248.5   119.0  10619.0  20.0  13006.5
# 17  2025-05-23--12h-24m-09s  2019.5    78.0  11218.0  14.5  13330.0
# 18  2025-05-23--12h-24m-13s  1655.5    52.0  11337.0  11.0  13055.5
# 19  2025-05-23--12h-24m-17s  1374.0    27.0  11486.0  11.5  12898.5
# 20  2025-05-23--12h-24m-21s  1127.0    15.0  11863.0   9.0  13014.0
# 21  2025-05-23--12h-24m-25s   881.5    12.0  12207.0   7.5  13108.0
# 22  2025-05-23--12h-24m-29s   723.5     4.0  12145.0   6.0  12878.5
# 23  2025-05-23--12h-24m-33s   531.5     2.0  12343.0   5.0  12881.5
# 24  2025-05-23--12h-24m-37s   404.0     1.0  12416.0   7.5  12828.5
# 25  2025-05-23--12h-24m-41s   304.5     0.0  12357.0   4.5  12666.0
# 26  2025-05-23--12h-24m-45s   254.0     0.0  12765.0   4.0  13023.0
# 27  2025-05-23--12h-24m-49s   254.0     0.0  12878.0   4.0  13136.0

# %%
df_pivoted_sum["theta_estimate"] = np.arccos(
    (df_pivoted_sum["DB_H"] - df_pivoted_sum["DB_V"]) / df_pivoted_sum["N"]
)
df_pivoted_sum["delta_phi_estimate"] = np.arctan(
    np.sqrt(df_pivoted_sum["C"] / df_pivoted_sum["SB"])
)
df_pivoted_sum
# Out:
#                    data_dir       C    DB_H     DB_V    SB        N  \
# 0   2025-05-23--12h-23m-01s  6559.0  2908.0   3974.0  38.5  13479.5
# 1   2025-05-23--12h-23m-05s  6506.5  2586.0   4264.0  34.5  13391.0
# 2   2025-05-23--12h-23m-09s  6430.0  2259.0   4803.0  29.0  13521.0
# 3   2025-05-23--12h-23m-13s  6199.5  2013.0   5220.0  35.0  13467.5
# 4   2025-05-23--12h-23m-17s  6072.5  1722.0   5613.0  37.0  13444.5
# 5   2025-05-23--12h-23m-21s  5795.0  1437.0   5893.0  32.0  13157.0
# 6   2025-05-23--12h-23m-25s  5548.0  1197.0   6483.0  33.0  13261.0
# 7   2025-05-23--12h-23m-29s  5241.0  1008.0   6911.0  32.0  13192.0
# 8   2025-05-23--12h-23m-33s  5000.0   887.0   7302.0  25.0  13214.0
# 9   2025-05-23--12h-23m-37s  4641.5   718.0   7682.0  31.5  13073.0
# 10  2025-05-23--12h-23m-41s  4319.5   586.0   8200.0  25.5  13131.0
# 11  2025-05-23--12h-23m-45s  3984.0   503.0   8646.0  22.5  13155.5
# 12  2025-05-23--12h-23m-49s  3614.5   370.0   9101.0  25.0  13110.5
# 13  2025-05-23--12h-23m-53s  3337.0   287.0   9275.0  21.0  12920.0
# 14  2025-05-23--12h-23m-57s  2968.0   207.0   9993.0  16.0  13184.0
# 15  2025-05-23--12h-24m-01s  2513.0   168.0  10026.0  15.5  12722.5
# 16  2025-05-23--12h-24m-05s  2248.5   119.0  10619.0  20.0  13006.5
# 17  2025-05-23--12h-24m-09s  2019.5    78.0  11218.0  14.5  13330.0
# 18  2025-05-23--12h-24m-13s  1655.5    52.0  11337.0  11.0  13055.5
# 19  2025-05-23--12h-24m-17s  1374.0    27.0  11486.0  11.5  12898.5
# 20  2025-05-23--12h-24m-21s  1127.0    15.0  11863.0   9.0  13014.0
# 21  2025-05-23--12h-24m-25s   881.5    12.0  12207.0   7.5  13108.0
# 22  2025-05-23--12h-24m-29s   723.5     4.0  12145.0   6.0  12878.5
# 23  2025-05-23--12h-24m-33s   531.5     2.0  12343.0   5.0  12881.5
# 24  2025-05-23--12h-24m-37s   404.0     1.0  12416.0   7.5  12828.5
# 25  2025-05-23--12h-24m-41s   304.5     0.0  12357.0   4.5  12666.0
# 26  2025-05-23--12h-24m-45s   254.0     0.0  12765.0   4.0  13023.0
# 27  2025-05-23--12h-24m-49s   254.0     0.0  12878.0   4.0  13136.0
#
#     theta_estimate  delta_phi_estimate
# 0         1.649962            1.494331
# 1         1.696435            1.498107
# 2         1.760076            1.503740
# 3         1.811235            1.495800
# 4         1.864409            1.492896
# 5         1.916309            1.496622
# 6         1.980800            1.493825
# 7         2.034729            1.492816
# 8         2.077697            1.500203
# 9         2.132585            1.488601
# 10        2.189340            1.494113
# 11        2.238241            1.495787
# 12        2.299569            1.487821
# 13        2.340142            1.491633
# 14        2.407238            1.497506
# 15        2.457270            1.492421
# 16        2.510340            1.476762
# 17        2.560219            1.486263
# 18        2.614726            1.489462
# 19        2.664640            1.479564
# 20        2.715056            1.481670
# 21        2.766157            1.478817
# 22        2.801531            1.479981
# 23        2.850883            1.474107
# 24        2.887004            1.435379
# 25        2.920252            1.449824
# 26        2.942209            1.445958
# 27        2.943072            1.445958

# %%
df_pivoted_sum["theta_estimate_degrees"] = np.degrees(df_pivoted_sum["theta_estimate"])
df_pivoted_sum["delta_phi_estimate_degrees"] = np.degrees(df_pivoted_sum["delta_phi_estimate"])
df_pivoted_sum
# Out:
#                    data_dir       C    DB_H     DB_V    SB        N  \
# 0   2025-05-23--12h-23m-01s  6559.0  2908.0   3974.0  38.5  13479.5
# 1   2025-05-23--12h-23m-05s  6506.5  2586.0   4264.0  34.5  13391.0
# 2   2025-05-23--12h-23m-09s  6430.0  2259.0   4803.0  29.0  13521.0
# 3   2025-05-23--12h-23m-13s  6199.5  2013.0   5220.0  35.0  13467.5
# 4   2025-05-23--12h-23m-17s  6072.5  1722.0   5613.0  37.0  13444.5
# 5   2025-05-23--12h-23m-21s  5795.0  1437.0   5893.0  32.0  13157.0
# 6   2025-05-23--12h-23m-25s  5548.0  1197.0   6483.0  33.0  13261.0
# 7   2025-05-23--12h-23m-29s  5241.0  1008.0   6911.0  32.0  13192.0
# 8   2025-05-23--12h-23m-33s  5000.0   887.0   7302.0  25.0  13214.0
# 9   2025-05-23--12h-23m-37s  4641.5   718.0   7682.0  31.5  13073.0
# 10  2025-05-23--12h-23m-41s  4319.5   586.0   8200.0  25.5  13131.0
# 11  2025-05-23--12h-23m-45s  3984.0   503.0   8646.0  22.5  13155.5
# 12  2025-05-23--12h-23m-49s  3614.5   370.0   9101.0  25.0  13110.5
# 13  2025-05-23--12h-23m-53s  3337.0   287.0   9275.0  21.0  12920.0
# 14  2025-05-23--12h-23m-57s  2968.0   207.0   9993.0  16.0  13184.0
# 15  2025-05-23--12h-24m-01s  2513.0   168.0  10026.0  15.5  12722.5
# 16  2025-05-23--12h-24m-05s  2248.5   119.0  10619.0  20.0  13006.5
# 17  2025-05-23--12h-24m-09s  2019.5    78.0  11218.0  14.5  13330.0
# 18  2025-05-23--12h-24m-13s  1655.5    52.0  11337.0  11.0  13055.5
# 19  2025-05-23--12h-24m-17s  1374.0    27.0  11486.0  11.5  12898.5
# 20  2025-05-23--12h-24m-21s  1127.0    15.0  11863.0   9.0  13014.0
# 21  2025-05-23--12h-24m-25s   881.5    12.0  12207.0   7.5  13108.0
# 22  2025-05-23--12h-24m-29s   723.5     4.0  12145.0   6.0  12878.5
# 23  2025-05-23--12h-24m-33s   531.5     2.0  12343.0   5.0  12881.5
# 24  2025-05-23--12h-24m-37s   404.0     1.0  12416.0   7.5  12828.5
# 25  2025-05-23--12h-24m-41s   304.5     0.0  12357.0   4.5  12666.0
# 26  2025-05-23--12h-24m-45s   254.0     0.0  12765.0   4.0  13023.0
# 27  2025-05-23--12h-24m-49s   254.0     0.0  12878.0   4.0  13136.0
#
#     theta_estimate  delta_phi_estimate  theta_estimate_degrees  \
# 0         1.649962            1.494331               94.535861
# 1         1.696435            1.498107               97.198545
# 2         1.760076            1.503740              100.844943
# 3         1.811235            1.495800              103.776129
# 4         1.864409            1.492896              106.822758
# 5         1.916309            1.496622              109.796414
# 6         1.980800            1.493825              113.491466
# 7         2.034729            1.492816              116.581360
# 8         2.077697            1.500203              119.043267
# 9         2.132585            1.488601              122.188132
# 10        2.189340            1.494113              125.439938
# 11        2.238241            1.495787              128.241735
# 12        2.299569            1.487821              131.755614
# 13        2.340142            1.491633              134.080283
# 14        2.407238            1.497506              137.924577
# 15        2.457270            1.492421              140.791228
# 16        2.510340            1.476762              143.831866
# 17        2.560219            1.486263              146.689729
# 18        2.614726            1.489462              149.812743
# 19        2.664640            1.479564              152.672610
# 20        2.715056            1.481670              155.561266
# 21        2.766157            1.478817              158.489108
# 22        2.801531            1.479981              160.515887
# 23        2.850883            1.474107              163.343543
# 24        2.887004            1.435379              165.413169
# 25        2.920252            1.449824              167.318109
# 26        2.942209            1.445958              168.576174
# 27        2.943072            1.445958              168.625579
#
#     delta_phi_estimate_degrees
# 0                    85.618865
# 1                    85.835215
# 2                    86.157937
# 3                    85.703023
# 4                    85.536660
# 5                    85.750152
# 6                    85.589859
# 7                    85.532043
# 8                    85.955309
# 9                    85.290561
# 10                   85.606369
# 11                   85.702275
# 12                   85.245879
# 13                   85.464286
# 14                   85.800747
# 15                   85.509427
# 16                   84.612237
# 17                   85.156620
# 18                   85.339900
# 19                   84.772778
# 20                   84.893423
# 21                   84.729948
# 22                   84.796654
# 23                   84.460129
# 24                   82.241165
# 25                   83.068784
# 26                   82.847277
# 27                   82.847277

# %%
# For each row, save the results to a CSV file

for index, row in df_pivoted_sum.iterrows():
    data_dir = row["data_dir"]
    theta_estimate = row["theta_estimate_degrees"]
    delta_phi_estimate = row["delta_phi_estimate_degrees"]
    
    # Create a new DataFrame for the current row
    results = pd.DataFrame({
        "estimation_label": ["C", "SB", "DB_H", "DB_V"],
        "scaled_coincidences": [row["C"], row["SB"], row["DB_H"], row["DB_V"]]
    })
    
    # Save the results to a CSV file
    results.to_csv(os.path.join(data_folder, data_dir, "scaled_coincidences.csv"), index=False)
    
    # Save the theta and delta_phi estimates to a CSV file
    theta_delta_phi = pd.DataFrame({
        "theta_estimate": [theta_estimate],
        "delta_phi_estimate": [delta_phi_estimate]
    })
    theta_delta_phi.to_csv(os.path.join(data_folder, data_dir, "theta_delta_phi_estimates.csv"), index=False)
